# %% [markdown]
# #Project Description:
# The Expense Management System is a Python-based application designed to streamline the process of tracking and managing expenses within an organization. The system allows users, typically HR personnel or finance managers, to input and analyze expense data efficiently.
#
# Key Features:
# 1. **Expense Tracking:** Users can add new expenses to the system by providing details such as date, description, category, amount, employee ID, and department.
# 2. **Expense Reporting:** The system generates insightful expense reports based on user-defined filters, including employee ID, department, and date range. This feature enables users to view expense data in a more organized and digestible format.
# 3. **Data Analysis:** The system provides basic data analysis capabilities, such as generating pie charts to visualize the distribution of expenses by category. This allows users to gain valuable insights into spending patterns and identify areas for optimization.
# 4. **Flexibility:** Users have the flexibility to filter expense data based on specific criteria, such as employee ID, department, and date range. This customization ensures that users can tailor expense reports to their unique requirements.
# 5. **Ease of Use:** The system features a user-friendly command-line interface that simplifies the process of adding expenses and generating reports. Users can navigate through the system intuitively and perform tasks efficiently.
#
# Overall, the Expense Management System offers a practical solution for organizations to track, analyze, and manage expenses effectively. By providing valuable insights into spending patterns and facilitating informed decision-making, the system contributes to better financial management and organizational efficiency.

# %%
import matplotlib.pyplot as plt

def add_expense(expenses):
    date = input("Enter the date of the expense: ")
    description = input("Enter a description for the expense: ")
    category = input("Enter the category of the expense: ")
    amount = float(input("Enter the amount of the expense: "))
    expenses.append({'Date': date, 'Description': description, 'Category': category, 'Amount': amount})

def generate_report(expenses):
    category_count = {}
    for expense in expenses:
        category = expense['Category']
        if category in category_count:
            category_count[category] += 1
        else:
            category_count[category] = 1

    labels = list(category_count.keys())
    sizes = list(category_count.values())

    plt.pie(sizes, labels=labels, autopct='%1.1f%%')
    plt.axis('equal')
    plt.title('Expense Distribution by Category')
    plt.show()

def main():
    expenses = []
    while True:
        print("\nExpense Management System\n")
        print("1. Add Expense")
        print("2. Generate Expense Report")
        print("3. Exit")
        choice = input("\nEnter your choice: ")

        if choice == '1':
            add_expense(expenses)
        elif choice == '2':
            generate_report(expenses)
        elif choice == '3':
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 1
# Enter the date of the expense: 2024-17-03
# Enter a description for the expense: cab
# Enter the category of the expense: travelling
# Enter the amount of the expense: 5000
#
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 2
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 1
# Enter the date of the expense: 2024-16-03
# Enter a description for the expense: food
# Enter the category of the expense: customer care
# Enter the amount of the expense: 7000
#
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 2
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 3
# Exiting...

# %% [markdown]
# #INFERENCE
# It an expense management system. It allows users to enter expense data and provides basic data analysis in the form of a pie chart.
# This script provides a simple command-line interface for users to add expenses and generate a pie chart showing the distribution of expenses by category. The expenses are stored in a list of dictionaries. The add_expense function allows users to input expense details, and the generate_report function generates a pie chart based on the categories of expenses.

# %%
import matplotlib.pyplot as plt
from datetime import datetime

def add_expense(expenses):
    date = input("Enter the date of the expense (YYYY-MM-DD): ")
    description = input("Enter a description for the expense: ")
    category = input("Enter the category of the expense: ")
    amount = float(input("Enter the amount of the expense: "))
    employee_id = input("Enter the employee ID: ")
    department = input("Enter the department: ")
    expenses.append({'Date': date, 'Description': description, 'Category': category, 'Amount': amount,
                     'EmployeeID': employee_id, 'Department': department})

def generate_report(expenses):
    filtered_expenses = filter_expenses(expenses)
    category_count = {}
    for expense in filtered_expenses:
        category = expense['Category']
        if category in category_count:
            category_count[category] += 1
        else:
            category_count[category] = 1

    labels = list(category_count.keys())
    sizes = list(category_count.values())

    plt.pie(sizes, labels=labels, autopct='%1.1f%%')
    plt.axis('equal')
    plt.title('Expense Distribution by Category')
    plt.show()

def filter_expenses(expenses):
    filtered_expenses = []
    employee_id = input("Enter employee ID (leave blank for all employees): ")
    department = input("Enter department (leave blank for all departments): ")
    start_date = input("Enter start date (YYYY-MM-DD) (leave blank for all dates): ")
    end_date = input("Enter end date (YYYY-MM-DD) (leave blank for all dates): ")

    for expense in expenses:
        if (not employee_id or expense['EmployeeID'] == employee_id) and \
           (not department or expense['Department'] == department) and \
           (not start_date or expense['Date'] >= start_date) and \
           (not end_date or expense['Date'] <= end_date):
            filtered_expenses.append(expense)

    return filtered_expenses

def main():
    expenses = []
    while True:
        print("\nExpense Management System\n")
        print("1. Add Expense")
        print("2. Generate Expense Report")
        print("3. Exit")
        choice = input("\nEnter your choice: ")

        if choice == '1':
            add_expense(expenses)
        elif choice == '2':
            generate_report(expenses)
        elif choice == '3':
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 1
# Enter the date of the expense (YYYY-MM-DD): 2024-03-17
# Enter a description for the expense: food for clients
# Enter the category of the expense: Food & Beverages
# Enter the amount of the expense: 2000
# Enter the employee ID: 1
# Enter the department: sales department
#
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 1
# Enter the date of the expense (YYYY-MM-DD): 2024-03-16
# Enter a description for the expense: repaire work
# Enter the category of the expense: Development
# Enter the amount of the expense: 7000
# Enter the employee ID: 3
# Enter the department: Development cell
#
# Expense Management System
#
# 1. Add Expense
# 2. Generate Expense Report
# 3. Exit
#
# Enter your choice: 1
# Enter the date of the expense (YYYY-MM-DD): 2024-03-15
# Enter a description for the expense: Cab
# ...

# %% [markdown]
# #INFERENCE
# In this modified version, the filter_expenses function allows the HR to filter expenses based on employee ID, department, and date range. The generate_report function now calls filter_expenses to obtain filtered expenses before generating the pie chart. The user is prompted to enter the desired filters before generating the report.
#
# This modification provides more flexibility for HR to view expense reports tailored to their specific requirements.

# %% [markdown]
# #Creators note
# While the development of web pages or apps for expense management is common, this project demonstrates that sophisticated solutions can be achieved solely through the conceptual knowledge and basic coding skills of developers. Utilizing simple programming techniques, such as Python, the Expense Management System proves that not every solution requires complex technologies or reliance on existing online platforms. By focusing on the fundamentals, developers can create effective tools tailored to specific needs without the overhead of integrating with external services or applications.
